# %%
# 4.1

# Choose a secret number between 1 and 10
secret = 7

# Choose a guess number between 1 and 10
guess = 5

# Conditional tests to print the result
if guess < secret:
    print('too low')
elif guess > secret:
    print('too high')
else:
    print('just right')


#4.2


# Assign True or False to the variables small and green
small = True
green = False

# if/else statements to print the matching fruit/vegetable
if small and green:
    print('pea')
elif small and not green:
    print('cherry')
elif not small and green:
    print('watermelon')
else:
    print('pumpkin')


# 6.1

# Define the list
numbers = [3, 2, 1, 0]

# Use a for loop to print the values
for num in numbers:
    print(num)


# 6.2

# Assign the values
guess_me = 7
number = 1

# Use a while loop to compare number with guess_me
while True:
    if number < guess_me:
        print('too low')
    elif number == guess_me:
        print('found it!')
        break
    elif number > guess_me:
        print('oops')
        break
    number += 1


# 6.3

# Assign the value
guess_me = 5

# Use a for loop to iterate over range(10)
for number in range(10):
    if number < guess_me:
        print('too low')
    elif number == guess_me:
        print('found it!')
        break
    elif number > guess_me:
        print('oops')
        break
# Out:
# too low
# cherry
# 3
# 2
# 1
# 0
# too low
# too low
# too low
# too low
# too low
# too low
# found it!
# too low
# too low
# too low
# too low
# too low
# found it!
